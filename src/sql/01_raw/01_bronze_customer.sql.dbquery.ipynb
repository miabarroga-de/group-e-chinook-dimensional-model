-- %%
USE CATALOG chinook;
USE SCHEMA ge_raw;

CREATE TABLE IF NOT EXISTS chinook.ge_raw.customer_raw
USING DELTA
AS
SELECT *
FROM read_files(
    '/Volumes/workspace/default/ftw-b12/shared/week05/chinook_csv/Customer.csv',
    format => 'csv',
    header => true,
    inferSchema => true
);
