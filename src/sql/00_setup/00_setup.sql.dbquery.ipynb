-- %%
CREATE CATALOG IF NOT EXISTS chinook;
USE CATALOG chinook;

-- Raw tables loaded from the original CSV files.
CREATE SCHEMA IF NOT EXISTS ge_raw;

-- Cleaned and standardized tables.
CREATE SCHEMA IF NOT EXISTS ge_clean;

-- Dimension and fact tables.
CREATE SCHEMA IF NOT EXISTS ge_mart;

-- Data-quality results and invalid records.
CREATE SCHEMA IF NOT EXISTS ge_quality;
